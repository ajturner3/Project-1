# %%
import pandas as pd

# %%
import os

# %%
os.listdir('.')
# Out:
# ['CleaningData.ipynb', 'demo_state_homeless.xlsx', '.ipynb_checkpoints']

# %%
df = pd.read_excel('demo_state_homeless.xlsx', sheet_name="2020")

# %%
years = [2007,2008,2009,2010,2011,2012,2013,2014,2015,2016,2017,2018,2019,2020]
years_columns_list = {}


for year in years:
    column_name1 = 'Sheltered ED Homeless - Male, '+str(year)
    column_name2 = 'Sheltered ED Homeless - Female, '+str(year)
    column_name3 = 'Sheltered ED Homeless - Transgender, '+str(year)
    column_name4 = 'Sheltered ED Homeless - Gender Non-Conforming, '+str(year)
    
    years_columns_list[year] = [column_name1, column_name2, column_name3, column_name4]

# %%
the_dict = {}

# %%
the_dict[2010] = ['Male', 'Female', 'Transgender', 'Gender Non-Conforming']
the_dict[2011] = ['Male', 'Female', 'Transgender', 'Gender Non-Conforming']
the_dict[2012] = ['Male', 'Female', 'Transgender', 'Gender Non-Conforming']
the_dict[2013] = ['Male', 'Female', 'Transgender', 'Gender Non-Conforming']
the_dict[2014] = ['Male', 'Female', 'Transgender', 'Gender Non-Conforming']
the_dict[2015] = ['Male', 'Female', 'Transgender', 'Gender Non-Conforming']
the_dict[2016] = ['Male', 'Female', 'Transgender', 'Gender Non-Conforming']
the_dict[2017] = ['Male', 'Female', 'Transgender', 'Gender Non-Conforming']
the_dict[2018] = ['Male', 'Female', 'Transgender', 'Gender Non-Conforming']
the_dict[2019] = ['Male', 'Female', 'Transgender', 'Gender Non-Conforming']
the_dict[2020] = ['Male', 'Female', 'Transgender', 'Gender Non-Conforming']

# %%
years_columns_list
# Out:
# {2007: ['Sheltered ED Homeless - Male, 2007',
#   'Sheltered ED Homeless - Female, 2007',
#   'Sheltered ED Homeless - Transgender, 2007',
#   'Sheltered ED Homeless - Gender Non-Conforming, 2007'],
#  2008: ['Sheltered ED Homeless - Male, 2008',
#   'Sheltered ED Homeless - Female, 2008',
#   'Sheltered ED Homeless - Transgender, 2008',
#   'Sheltered ED Homeless - Gender Non-Conforming, 2008'],
#  2009: ['Sheltered ED Homeless - Male, 2009',
#   'Sheltered ED Homeless - Female, 2009',
#   'Sheltered ED Homeless - Transgender, 2009',
#   'Sheltered ED Homeless - Gender Non-Conforming, 2009'],
#  2010: ['Sheltered ED Homeless - Male, 2010',
#   'Sheltered ED Homeless - Female, 2010',
#   'Sheltered ED Homeless - Transgender, 2010',
#   'Sheltered ED Homeless - Gender Non-Conforming, 2010'],
#  2011: ['Sheltered ED Homeless - Male, 2011',
#   'Sheltered ED Homeless - Female, 2011',
#   'Sheltered ED Homeless - Transgender, 2011',
# ...

# %%
years_columns_list[2007]
# Out:
# ['Sheltered ED Homeless - Male, 2007',
#  'Sheltered ED Homeless - Female, 2007',
#  'Sheltered ED Homeless - Transgender, 2007',
#  'Sheltered ED Homeless - Gender Non-Conforming, 2007']

# %%
df2017 = pd.read_excel('demo_state_homeless.xlsx', sheet_name='2017')

# %%
list(df2017.columns)
# Out:
# ['State',
#  'Number of CoCs',
#  'Overall Homeless, 2017',
#  'Overall Homeless - Under 18, 2017',
#  'Overall Homeless - Age 18 to 24, 2017',
#  'Overall Homeless - Over 24, 2017',
#  'Overall Homeless - Female, 2017',
#  'Overall Homeless - Male, 2017',
#  'Overall Homeless - Transgender, 2017',
#  'Overall Homeless - Gender Non-Conforming, 2017',
#  'Overall Homeless - Non-Hispanic/Non-Latino, 2017',
#  'Overall Homeless - Hispanic/Latino, 2017',
#  'Overall Homeless - White, 2017',
#  'Overall Homeless - Black or African American, 2017',
#  'Overall Homeless - Asian, 2017',
#  'Overall Homeless - American Indian or Alaska Native, 2017',
#  'Overall Homeless - Native Hawaiian or Other Pacific Islander, 2017',
#  'Overall Homeless - Multiple Races, 2017',
#  'Sheltered ES Homeless, 2017',
#  'Sheltered ES Homeless - Under 18, 2017',
#  'Sheltered ES Homeless - Age 18 to 24, 2017',
#  'Sheltered ES Homeless - Over 24, 2017',
#  'Sheltered ES Homeless - Female, 2017',
# ...

# %%
df_list = []
for year in years:
    df = pd.read_excel('demo_state_homeless.xlsx', sheet_name=str(year))
    df = df[years_columns_list[year]]
    df_list.append(df)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 4
#       2 for year in years:
#       3     df = pd.read_excel('demo_state_homeless.xlsx', sheet_name=str(year))
# ----> 4     df = df[years_columns_list[year]]
#       5     df_list.append(df)
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# ...

# %%
selected_columns = [col for col in df.columns if 'Male']

# %%
list(df.columns)
# Out:
# ['State',
#  'Number of CoCs',
#  'Overall Homeless, 2020',
#  'Overall Homeless - Under 18, 2020',
#  'Overall Homeless - Age 18 to 24, 2020',
#  'Overall Homeless - Over 24, 2020',
#  'Overall Homeless - Female, 2020',
#  'Overall Homeless - Male, 2020',
#  'Overall Homeless - Transgender, 2020',
#  'Overall Homeless - Gender Non-Conforming, 2020',
#  'Overall Homeless - Non-Hispanic/Non-Latino, 2020',
#  'Overall Homeless - Hispanic/Latino, 2020',
#  'Overall Homeless - White, 2020',
#  'Overall Homeless - Black or African American, 2020',
#  'Overall Homeless - Asian, 2020',
#  'Overall Homeless - American Indian or Alaska Native, 2020',
#  'Overall Homeless - Native Hawaiian or Other Pacific Islander, 2020',
#  'Overall Homeless - Multiple Races, 2020',
#  'Sheltered ES Homeless, 2020',
#  'Sheltered ES Homeless - Under 18, 2020',
#  'Sheltered ES Homeless - Age 18 to 24, 2020',
#  'Sheltered ES Homeless - Over 24, 2020',
#  'Sheltered ES Homeless - Female, 2020',
# ...
